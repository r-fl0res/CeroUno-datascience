# %% [markdown]
# # Proyecto - La Divina comedia
# ## 1. Antes de empezar
# - Planea tu código: Antes de escribir código debemos sentarnos, pensar que hacer, hacer un plan (se le llama pseudocódigo) y luego ya tienes permiso de escribir código.
# - ¿No se que hacer? Google it! Seguramente en internet tiene seguramente las respuesta
# - Divide y conquistaras: trabaja segmentando el código en celdas y revisa que cada acción importante se realice la manera correcta
# - Si crees que usaras recurrentemente la sección de código que hace algo, sería conveniente hacer una función ¿no?
#
#
# ## 2. Descripción
#
# Para este ejemplo usaremos del texto en ingles de *La Divina Comedia* escrita por Dante Alighieri y fue descargado desde *Project Gutenberg* con nombre **8800.txt**. Existen muchas maneras de realizar este ejercicio, no te preocupes por lo que hacen los demas. Realiza mediante comandos, no uses funciones hasta que se te pida.
#
#
# **Preguntas**
#
#
# - 1¿Cuántas palabras existen en los primeros 5,000 caracteres?
# - 2¿Cuántas palabras únicas existen en el mismo rango?
# - 3¿Importan las mayúsculas y minúsculas?
# - 4¿Cuántas veces aparece la palabra **the** en ese rango?
# - 5¿Puedo saber cuantas veces existe una palabra en el texto cargado?
# si o no
# - 6Crea un diccionario donde asignes el número de apariciones a la palabra existente
# La respuesta seria un diccionario con las palabras unicas, yo creo que con 3 palabras esta bien
# ej {The:10
# tree: 12
# boy:6}
# - 7¿Qué pasa con los signos de puntuación, es decir, 'me', 'me;', 'me.', 'me?' y 'me,' son iguales?
# si o no, (todas son distintas por las puntuaciones)
#
# - 8¿Cuáles existen? ¿Estan todos en la misma posición?
# cuales son los signos de puntuacion que existen, ps no stan en la misma posicion
#
# - 9Elimina los signos de puntuación y realiza el mismo ejercicio
#
#
# Ahora crea funciones para realizar las mismas preguntas y usalas para analizar el texto completo (todo un reto).

# %% [markdown]
# #### RESOLVIENDO POR COMANDOS

# %%
#primer pregunta
f=open("8800.txt","r") #920
f.seek(1315)
preg1= f.read(5000)
n=preg1.split()
y = len(n)
print(y)
# Out:
# 900

# %%
#Segunda pregunta (unicas sin mayus)
seteado = set(n)
print(len(seteado))
# Out:
# 551

# %%
#3er pregunta (Favor de ejecutar despues de 6ta preg)
#si, para el conteo de palabras no importa si no son unicas pero por ejemplo si vas a revisar la similitud entre dos textos y quieres que The y the sean iguales,
#debes tomar en cuenta
print (len(setmayus))
# Out:
# 510

# %%
#4ta pregunta (ejecutar primero 6ta pregunta por el despues de mayus)
#antes de mayus
r = n.count('the')
print(r)
#despues de mayus
u = len(unimayus)
print(u)

#5ta pregunta¿Puedo saber cuantas veces existe una palabra en el texto cargado?
#R. Si demostrado en la pregunta 4
# Out:
# 41
# 510

# %%
#6ta pregunta
mayus = str.upper(preg1)
listmayus = mayus.split()
setmayus =set(listmayus)
unimayus = list(setmayus)

for i in unimayus:
    cadena1 =str(unimayus.count(i))
    print(i+':'+cadena1)
# Out:
# ORDER;:1
# MEMORY:1
# HAVE:1
# GLORY,:1
# THYSELF:1
# WITH:1
# THUS:1
# INFLAM'D:1
# MAK'ST:1
# NEWLY,:1
# LONG,:1
# WHOM:1
# ONLY:1
# DRAWN.:1
# JOY:1
# BOILING:1
# CAUSE.:1
# FIRE,:1
# CASTS;:1
# PRIMAL:1
# UP.:1
# THEIR:1
# BENT:1
# HITHER:1
# MAKES:1
# WORDS:1
# NE'ER:1
# THIS:1
# DIVERSELY,:1
# WAS:1
# SURPASSETH:1
# NEED:1
# FOLIAGE,:1
# ME.:1
# WILLS:1
# DAY:1
# THREEFOLD:1
# CLEARLY:1
# GAIN:1
# YET:1
# PASS'D:1
# SEEM'D:1
# MINE:1
# BEAR:1
# PITEOUS:1
# SPHERE:1
# BROWS:1
# PASSAGES,:1
# WONT:1
# AID,:1
# GOD:1
# IRON:1
# BLACKNESS:1
# PILGRIM:1
# BRIGHT:1
# BEYOND:1
# MOV'D,:1
# SOURCE.:1
# A:1
# SET:1
# LAKE:1
# FIRST-RAIS'D:1
# COURSE;:1
# GREAT:1
# HIM:1
# REST:1
# DWELLING:1
# DOUBT:1
# LEAVES;:1
# AIM'D:1
# "ALREADY:1
# INTO:1
# GOD.:1
# FLAME,:1
# DEPTH:1
# PEER:1
# UNSHEATH'D.:1
# HAPPY:1
# BECAME:1
# HAND:1
# END:1
# THEREFORE:1
# BOTH:1
# EACH:1
# WHITENESS:1
# TEMPER:1
# VAST:1
# SATISFIED,:1
# BODIES:1
# THEN:1
# WHO:1
# MOV'D:1
# EVER:1
# THINGS:1
# PART:1
# ...

# %%
#7 pregunta
#R.- En caso de tener los signos de puntuacion asi no podrias encontrarlos si tienes tu texto por ejemplo separado en una lista porque el signo iria concatenado al texto entoncs no lo reconoceria como : pero si como me:
#8 pregunta
#encontrar los caracteres especiales del texto
letras= 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ '
letrasl=list(letras)
texto = list(preg1)
sl1 = set(letrasl)
stxt = set(texto)
diff = stxt.difference(sl1)
diff.remove('\n')
print(diff)
# Out:
# {'!', '"', "'", ',', ';', '-', ':', '(', ')', '.'}

# %%
#9elimina los signos de puntuacion del texto no terminado
sdiff = str(diff)
print(preg1)
print(sdiff)
for char in (preg1):
    n = 'false'
    for i in (sdiff):
        if char == i:
            n= 'true'
            break
if n == 'true':
    preg12 += ' '
else:
    preg12 += char
print(preg12)
# Out:
# His glory, by whose might all things are mov'd,
# Pierces the universe, and in one part
# Sheds more resplendence, elsewhere less.  In heav'n,
# That largeliest of his light partakes, was I,
# Witness of things, which to relate again
# Surpasseth power of him who comes from thence;
# For that, so near approaching its desire
# Our intellect is to such depth absorb'd,
# That memory cannot follow.  Nathless all,
# That in my thoughts I of that sacred realm
# Could store, shall now be matter of my song.
#
# Benign Apollo! this last labour aid,
# And make me such a vessel of thy worth,
# As thy own laurel claims of me belov'd.
# Thus far hath one of steep Parnassus' brows
# Suffic'd me; henceforth there is need of both
# For my remaining enterprise Do thou
# Enter into my bosom, and there breathe
# So, as when Marsyas by thy hand was dragg'd
# Forth from his limbs unsheath'd.  O power divine!
# If thou to me of shine impart so much,
# That of that happy realm the shadow'd form
# ...

# %% [markdown]
# LO DE LAS FUNCIONES SE PUSO EN ARCHIVO 'S3-PBS3 FUNCIONES'

# %% [markdown]
# <!-- ### print(len(preg1)) -->

# %% [markdown]
# ## 3. Comparación de resultados y métodos
#
# ¡Comparemos la lógica de sus códigos! Nadie piensa igual y la diversidad nos permite encontrar mejores soluciones mediante el diálogo.

# %% [markdown]
# ## 4. ¿Quieren más? - Recursos de apoyo
#
# - Platarformas: EDX, Coursera, Udemy, DataCamp
# - Empresas: IBM, Microsoft
# - Millones de páginas web
# - Cientos de libros (como los que ya les pasamos)
